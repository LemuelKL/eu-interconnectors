# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data_file = 'data/dap/_combined.csv'

# %%
df = pd.read_csv(data_file, index_col=0)

# %%
df
# Out:
#                               BE     DE     FR     LU     NL      UK     DK  \
# 2023-03-31 22:00:00+00:00  82.19  82.19  82.19  82.19  82.19  130.00  39.58
# 2023-03-31 23:00:00+00:00  63.90  63.90  63.90  63.90  63.90  118.87  36.62
# 2023-04-01 00:00:00+00:00  53.84  53.84  53.84  53.84  53.84  115.84  34.96
# 2023-04-01 01:00:00+00:00  44.39  38.83  42.50  38.83  53.99  115.60  35.52
# 2023-04-01 02:00:00+00:00  41.22  36.05  39.45  36.05  55.01  112.54  35.19
# ...                          ...    ...    ...    ...    ...     ...    ...
# 2023-11-01 18:00:00+00:00  71.80  66.57  71.90  66.57  74.97  217.80  64.97
# 2023-11-01 19:00:00+00:00  57.48  53.15  56.59  53.15  61.18  204.01  53.15
# 2023-11-01 20:00:00+00:00  40.15  39.51  40.87  39.51  39.83  193.00  31.68
# 2023-11-01 21:00:00+00:00  40.77  34.17  38.83  34.17  48.40  145.00  19.11
# 2023-11-01 22:00:00+00:00  23.00  18.76  21.68  18.76  28.20  133.32  16.95
#
# ...

# %%
# Set plot size
figsize = (8, 6)
plt.figure(figsize=figsize)

plt.xlabel("Time")
plt.ylabel("Price")
plt.title("Historical DAP Price")
df.iloc[:48].plot()
# Out:
# <Axes: >
